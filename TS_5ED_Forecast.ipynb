# %%
# !git clone https://github.com/RoshanVarghese/ElectricityDemandForecasts.git

# %cd ElectricityDemandForecasts

# !pip install gradio tensorflow statsmodels scikit-learn

# !python app.py
# Out:
# Cloning into 'ElectricityDemandForecasts'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 23 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 207.71 KiB | 2.04 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/ElectricityDemandForecasts
# ...
# 2025-08-21 10:47:31.307806: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755773251.337301    1230 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
